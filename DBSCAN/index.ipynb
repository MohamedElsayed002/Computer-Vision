# %% [markdown]
# # DBSCAN Clustering Intution

# %%
from sklearn.cluster import DBSCAN 
from matplotlib import pyplot as plt
import numpy as np

# %%
X = np.array([[1,2],[3,4],[4,3],[8,7],[7,8],[25,80]])

# %%
X
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [ 4,  3],
#        [ 8,  7],
#        [ 7,  8],
#        [25, 80]])

# %%
plt.scatter(X[:,0], X[:,1])

# %%
clustering = DBSCAN(eps=9,min_samples=6).fit_predict(X)

# %%
clustering
# Out:
# array([-1, -1, -1, -1, -1, -1], dtype=int64)

# %%
from sklearn.datasets import make_blobs 
from sklearn.neighbors import NearestNeighbors
import seaborn as sns 
sns.set()

# %%
X, y = make_blobs(n_samples=200,centers=4,cluster_std=0.60,random_state=0)
plt.scatter(X[:,0],X[:,1])

# %%
dbScanCluster = DBSCAN(eps=0.5,min_samples=5)
dbScanCluster.fit(X)
# Out:
# DBSCAN()

# %%
clusters = dbScanCluster.labels_

# %%
clusters
# Out:
# array([ 0,  1,  2, -1,  0,  2,  1, -1, -1,  2,  2,  0,  1,  1,  0, -1,  3,
#         3,  3,  0,  3,  1,  0,  1,  0,  0,  3,  0,  0,  2,  3,  2,  1,  0,
#         1, -1,  1,  2,  2,  3,  3,  3,  3,  2,  0,  1,  2, -1,  3,  2,  3,
#         1,  1,  3, -1,  3,  1,  0, -1,  0,  3,  2,  0,  2,  3,  2,  0, -1,
#         1,  1,  0,  0,  2,  2,  1,  3,  1,  1,  0,  0,  3,  2,  0, -1,  1,
#         2,  2,  0,  1, -1,  3,  3,  3,  2,  2,  0,  1,  3, -1,  2,  3,  0,
#         0,  3,  3,  1,  2,  0,  0,  2, -1,  1,  1,  0, -1,  2, -1,  1,  3,
#         2,  3, -1,  2,  0,  2,  1,  2,  1,  0,  2,  1,  0, -1,  3,  3,  1,
#         3,  3,  0,  3,  0,  1,  0,  0, -1,  0,  2,  0, -1, -1,  3,  3,  2,
#         1,  0,  2,  3,  1,  3,  0, -1,  0,  0,  1,  1,  3,  2,  0,  0,  1,
#         0,  2,  1,  3,  3,  3,  2, -1,  1, -1, -1,  0,  2,  0,  2, -1, -1,
#         3,  2,  3,  0,  0,  2,  3,  1,  1,  1,  2,  3,  0], dtype=int64)

# %%
clusters
# Out:
# array([ 0,  1,  2, -1,  0,  2,  1, -1, -1,  2,  2,  0,  1,  1,  0, -1,  3,
#         3,  3,  0,  3,  1,  0,  1,  0,  0,  3,  0,  0,  2,  3,  2,  1,  0,
#         1, -1,  1,  2,  2,  3,  3,  3,  3,  2,  0,  1,  2, -1,  3,  2,  3,
#         1,  1,  3, -1,  3,  1,  0, -1,  0,  3,  2,  0,  2,  3,  2,  0, -1,
#         1,  1,  0,  0,  2,  2,  1,  3,  1,  1,  0,  0,  3,  2,  0, -1,  1,
#         2,  2,  0,  1, -1,  3,  3,  3,  2,  2,  0,  1,  3, -1,  2,  3,  0,
#         0,  3,  3,  1,  2,  0,  0,  2, -1,  1,  1,  0, -1,  2, -1,  1,  3,
#         2,  3, -1,  2,  0,  2,  1,  2,  1,  0,  2,  1,  0, -1,  3,  3,  1,
#         3,  3,  0,  3,  0,  1,  0,  0, -1,  0,  2,  0, -1, -1,  3,  3,  2,
#         1,  0,  2,  3,  1,  3,  0, -1,  0,  0,  1,  1,  3,  2,  0,  0,  1,
#         0,  2,  1,  3,  3,  3,  2, -1,  1, -1, -1,  0,  2,  0,  2, -1, -1,
#         3,  2,  3,  0,  0,  2,  3,  1,  1,  1,  2,  3,  0], dtype=int64)
